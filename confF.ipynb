# %%
import numpy as np
import math
import cmath
import scipy.special
import matplotlib.pyplot as plt
import cv2
import sympy
import os
import tensorflow as tf
from tensorflow import keras
from keras import layers
from scipy.stats import ttest_ind

# %%
r=1/math.sqrt(2)
m=r**2
L=1/2*scipy.special.ellipk(m)*cmath.exp(math.pi/4*1j)

#conformal mapping from the unit square to the unit disk

def f(z):

    y=math.sqrt(2)*L*z
    phi = y.real
    psi = y.imag
    v0=scipy.special.ellipj(phi,m)
    v1=scipy.special.ellipj(psi,1-m)
    delta = v1[1]**2 + m*v0[0]**2*v1[0]**2 
    sni = (v0[0]*v1[2] + 1j*v0[1]*v0[2]*v1[0]*v1[1])/delta
    dni = (v0[2]*v1[1]*v1[2] - 1j*m*v0[0]*v0[1]*v1[0])/delta
    w=1/math.sqrt(2)/cmath.exp(math.pi/4*1j)*sni/dni

    return(w)

#conformal mapping from the unit disk to the unit square

def invf(z):

    omega=math.sqrt(2)*cmath.exp(math.pi/4*1j)*z/(1+1j*z**2)**(1/2)
    y=np.arcsin(omega)
    phi=y.real
    psi=y.imag
    #to avoid singularity of COT(phi) at zero add EPS
    eps=0.00001
    if abs(phi)<eps:
        phi=eps
    #finding the roots of the equation X^2 - (cot(phi)^2+m*sinh(psi)^2*csc(phi)^2-1+m)X - (1-m)*cot(phi)^2 = 0
    b = -(sympy.cot(phi)**2 + m*np.sinh(psi)**2*sympy.csc(phi)**2-1+m)
    c = -(1-m)*sympy.cot(phi)**2;
    X1 = -b/2+math.sqrt(b**2/4-c)
    if X1>=0:
        lam = sympy.acot(math.sqrt(X1))    
    if X1<0:
        X2 = -b/2-math.sqrt(b**2/4-c)
        lam = sympy.acot(math.sqrt(X2))
    if 1/m*(np.tan(phi)**2*sympy.cot(lam)**2-1)<0:
        mu=0
    else:
        mu = sympy.atan(math.sqrt(1/m*(np.tan(phi)**2*sympy.cot(lam)**2-1)))
    #change of variables taking into account periodicity ceil to the right
    lam = (-1)**np.floor(phi/math.pi*2)*lam + math.pi*np.ceil(phi/math.pi-0.5+eps)
    mu = np.sign(psi)*mu
    F1 = scipy.special.ellipkinc(float(lam),m)
    F2 = scipy.special.ellipkinc(float(mu),1-m)
    Fi = F1 + F2*1j
    w=1/(math.sqrt(2)*L)*Fi
    
    return(w)

z=-0.3+0.3j
w=f(z)
z1=invf(w)

print(abs(z-z1))
# Out:
# 7.850462293418876e-17

# %%
def squareToDisk(img):

  #the image is assumed to be a square!
  img_height=img.shape[0]

  #imgH is a vector telling the location of the points corresponding with the pixels of the image in the interval [-1,1]
  imgH=np.array(range(img_height))/(img_height-1)*2-1
 
  #u is the relative distance between two adjacent pixels
  u=imgH[1]-imgH[0]

  #we need the values of those points mapped from the unit square onto the unit disk that determine the pixels producing the final image
  #to obtain these values, we first need to find out the original locations of these pixel points before the mapping
  #this is done with the inverse mapping that maps the unit disk onto the unit square
  #after that, we compute the values of the pixel points with weighted means of the four vertices

  img1=np.zeros((img.shape))
  for i in range(img_height):
    for j in range(img_height):
      if imgH[i]**2+imgH[j]**2<1:
        z=complex(imgH[i],imgH[j])
        w=invf(z)
        i0=int(np.floor((w.real+1)/u))
        i1=(w.real+1)/u-i0
        j0=int(np.floor((w.imag+1)/u))
        j1=(w.imag+1)/u-j0
        if len(img.shape)==2:
          img1[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]
        else:
          for k in range(img.shape[2]):
            img1[i,j,k]=i1*j1*img[i0,j0,k]+(1-i1)*j1*img[i0+1,j0,k]+i1*(1-j1)*img[i0,j0+1,k]+(1-i1)*(1-j1)*img[i0+1,j0+1,k]

  return img1

# %%
def diskToSquare(img):

  img_height=img.shape[0]
  imgH=np.array(range(img_height))/(img_height-1)*2-1
  u=imgH[1]-imgH[0]

  img1=np.zeros((img.shape))
  for i in range(img_height):
    for j in range(img_height):
      z=complex(imgH[i],imgH[j])
      w=f(z)
      i0=int(np.floor((w.real+1)/u))
      i1=(w.real+1)/u-i0
      j0=int(np.floor((w.imag+1)/u))
      j1=(w.imag+1)/u-j0
      if len(img.shape)==2:
        img1[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]
      else:
        for k in range(img.shape[2]):
          img1[i,j,k]=i1*j1*img[i0,j0,k]+(1-i1)*j1*img[i0+1,j0,k]+i1*(1-j1)*img[i0,j0+1,k]+(1-i1)*(1-j1)*img[i0+1,j0+1,k]

  return img1

# %%
def mobius(img,alp):

  img_height=img.shape[0]
  imgH=np.array(range(img_height))/(img_height-1)*2-1
  u=imgH[1]-imgH[0]

  img1=np.zeros((img.shape))
  for i in range(img_height):
    for j in range(img_height):
      if imgH[i]**2+imgH[j]**2<1:
        z=complex(imgH[i],imgH[j])
        w=(z+alp)/(1+np.conj(alp)*z)
        i0=int(np.floor((w.real+1)/u))
        i1=(w.real+1)/u-i0
        j0=int(np.floor((w.imag+1)/u))
        j1=(w.imag+1)/u-j0
        if len(img.shape)==2:
          img1[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]
        else:
          for k in range(img.shape[2]):
            img1[i,j,k]=i1*j1*img[i0,j0,k]+(1-i1)*j1*img[i0+1,j0,k]+i1*(1-j1)*img[i0,j0+1,k]+(1-i1)*(1-j1)*img[i0+1,j0+1,k]

  return img1

# %%
def rotation(img,kul):

  img_height=img.shape[0]
  imgH=np.array(range(img_height))/(img_height-1)*2-1
  u=imgH[1]-imgH[0]

  img1=np.zeros((img.shape))
  for i in range(img_height):
    for j in range(img_height):
      if imgH[i]**2+imgH[j]**2<1:
        z=complex(imgH[i],imgH[j])
        w=z*cmath.exp(kul*1j)
        i0=int(np.floor((w.real+1)/u))
        i1=(w.real+1)/u-i0
        j0=int(np.floor((w.imag+1)/u))
        j1=(w.imag+1)/u-j0
        if len(img.shape)==2:
          img1[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]
        else:
          for k in range(img.shape[2]):
            img1[i,j,k]=i1*j1*img[i0,j0,k]+(1-i1)*j1*img[i0+1,j0,k]+i1*(1-j1)*img[i0,j0+1,k]+(1-i1)*(1-j1)*img[i0+1,j0+1,k]

  return img1

# %%
img_height=300
img=np.zeros((img_height,img_height))
for i in range(img_height):
  for j in range(img_height):
    if j%7>=1:
      img[i,j]=1
plt.imshow(img,cmap='gray')
plt.show()
img1=squareToDisk(img)
plt.imshow(img1,cmap='gray')
plt.show()
alp=0.3+0.3j
img2=mobius(img1,alp)
plt.imshow(img2,cmap='gray')
plt.show()
kul=math.pi/3
img3=rotation(img2,kul)
plt.imshow(img3,cmap='gray')
plt.show()
img4=diskToSquare(img3)
plt.imshow(img4,cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\assumptions.py:479, in make_property.<locals>.getit(self)
#     478 try:
# --> 479     return self._assumptions[fact]
#     480 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Oona\Documents\Pet\mobius\confF.ipynb Cell 7' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000006?line=6'>7</a> plt.imshow(img,cmap='gray')
#       <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000006?line=7'>8</a> plt.show()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000006?line=8'>9</a> img1=squareToDisk(img)
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000006?line=9'>10</a> plt.imshow(img1,cmap='gray')
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000006?line=10'>11</a> plt.show()
#
# c:\Users\Oona\Documents\Pet\mobius\confF.ipynb Cell 3' in squareToDisk(img)
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000002?line=19'>20</a> if imgH[i]**2+imgH[j]**2<1:
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000002?line=20'>21</a>   z=complex(imgH[i],imgH[j])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000002?line=21'>22</a>   w=invf(z)
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000002?line=22'>23</a>   i0=int(np.floor((w.real+1)/u))
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000002?line=23'>24</a>   i1=(w.real+1)/u-i0
#
# c:\Users\Oona\Documents\Pet\mobius\confF.ipynb Cell 2' in invf(z)
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000001?line=31'>32</a>     phi=eps
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000001?line=32'>33</a> #finding the roots of the equation X^2 - (cot(phi)^2+m*sinh(psi)^2*csc(phi)^2-1+m)X - (1-m)*cot(phi)^2 = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000001?line=33'>34</a> b = -(sympy.cot(phi)**2 + m*np.sinh(psi)**2*sympy.csc(phi)**2-1+m)
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000001?line=34'>35</a> c = -(1-m)*sympy.cot(phi)**2;
#      <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#ch0000001?line=35'>36</a> X1 = -b/2+math.sqrt(b**2/4-c)
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\function.py:476, in Function.__new__(cls, *args, **options)
#     468     raise TypeError(temp % {
#     469         'name': cls,
#     470         'qual': 'exactly' if len(cls.nargs) == 1 else 'at least',
#     471         'args': min(cls.nargs),
#     472         'plural': 's'*(min(cls.nargs) != 1),
#     473         'given': n})
#     475 evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 476 result = super().__new__(cls, *args, **options)
#     477 if evaluate and isinstance(result, cls) and result.args:
#     478     pr2 = min(cls._should_evalf(a) for a in result.args)
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\function.py:288, in Application.__new__(cls, *args, **options)
#     285     raise ValueError("Unknown options: %s" % options)
#     287 if evaluate:
# --> 288     evaluated = cls.eval(*args)
#     289     if evaluated is not None:
#     290         return evaluated
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\functions\elementary\trigonometric.py:1368, in cot.eval(cls, arg)
#    1366     if arg is S.NaN:
#    1367         return S.NaN
# -> 1368     if arg.is_zero:
#    1369         return S.ComplexInfinity
#    1371 if arg is S.ComplexInfinity:
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\assumptions.py:482, in make_property.<locals>.getit(self)
#     480 except KeyError:
#     481     if self._assumptions is self.default_assumptions:
# --> 482         self._assumptions = self.default_assumptions.copy()
#     483     return _ask(fact, self)
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\assumptions.py:462, in StdFactKB.copy(self)
#     461 def copy(self):
# --> 462     return self.__class__(self)
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\assumptions.py:459, in StdFactKB.__init__(self, facts)
#     457     self._generator = facts.generator
#     458 if facts:
# --> 459     self.deduce_all_facts(facts)
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\facts.py:533, in FactKB.deduce_all_facts(self, facts)
#     531 for bidx in beta_maytrigger:
#     532     bcond, bimpl = beta_rules[bidx]
# --> 533     if all(self.get(k) is v for k, v in bcond):
#     534         facts.append(bimpl)
#
# File c:\Users\Oona\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\facts.py:533, in <genexpr>(.0)
#     531 for bidx in beta_maytrigger:
#     532     bcond, bimpl = beta_rules[bidx]
# --> 533     if all(self.get(k) is v for k, v in bcond):
#     534         facts.append(bimpl)
#
# KeyboardInterrupt:

# %%
img_height=100
img=cv2.imread('C:/Users/Oona/Documents/Tpc/myLittleCNN/test/kukkia/IMG_1209.JPG')
img=cv2.resize(img,(img_height,img_height))
img=(img-np.min(img))/(np.max(img)-np.min(img))
imgH=np.array(range(img_height))/(img_height-1)*2-1
for i in range(img_height):
  for j in range(img_height):
    img[i,j,:]=img[i,j,0]
    if imgH[i]**2+imgH[j]**2>1:
      img[i,j,:]=0
plt.imshow(img,cmap='gray')
plt.show()
print(img.shape)
# Out:
# (100, 100, 3)

# %%
img_height=100

img=cv2.imread('C:/Users/Oona/Documents/Tpc/myLittleCNN/test/kukkia/IMG_1209.JPG')
img=cv2.resize(img,(img_height,img_height))
img=(img-np.min(img))/(np.max(img)-np.min(img))

plt.imshow(img,cmap='gray')
plt.show()
img1=squareToDisk(img)
plt.imshow(img1,cmap='gray')
plt.show()
plt.imshow(diskToSquare(img1),cmap='gray')
plt.show()

# %%
def lineImgs(img):

  img_height=img.shape[0]

  imgH=np.array(range(img_height))/(img_height-1)*2-1
 
  u=imgH[1]-imgH[0]

  img1=np.zeros((img.shape))
  img2=np.zeros((img.shape))
  img3=np.zeros((img.shape))

  for i in range(img_height):
    for j in range(img_height):
      z=complex(imgH[i],imgH[j])
      x=f(z)
      kul=math.pi/3
      y=x*cmath.exp(kul*1j)
      alp=0.3+0.3j
      v=(y+alp)/(1+np.conj(alp)*y)
      w=invf(v)
      i0=min(int(np.floor((w.real+1)/u)),img_height-2)
      i1=(w.real+1)/u-i0
      j0=min(int(np.floor((w.imag+1)/u)),img_height-2)
      j1=(w.imag+1)/u-j0
      img1[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]
      if abs(z)<1:
        y=z*cmath.exp(kul*1j)
        v=(y+alp)/(1+np.conj(alp)*y)
        w=invf(v)
        i0=min(int(np.floor((w.real+1)/u)),img_height-2)
        i1=(w.real+1)/u-i0
        j0=min(int(np.floor((w.imag+1)/u)),img_height-2)
        j1=(w.imag+1)/u-j0
        img2[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]
        v=(z+alp)/(1+np.conj(alp)*z)
        w=invf(v)
        i0=min(int(np.floor((w.real+1)/u)),img_height-2)
        i1=(w.real+1)/u-i0
        j0=min(int(np.floor((w.imag+1)/u)),img_height-2)
        j1=(w.imag+1)/u-j0
        img3[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]

  return [img1,img2,img3]

# %%
img_height=300
img=np.zeros((img_height,img_height))
for i in range(img_height):
  for j in range(img_height):
    if j%7>=1:
      img[i,j]=1
img0=squareToDisk(img)
img3,img2,img1=lineImgs(img)

# %%
plt.imshow(img3,cmap='gray')
fig=plt.gcf()
plt.xticks([],labels='')
plt.yticks([],labels='')
plt.tick_params(left = False,top=False)
plt.show()
fig.savefig('l_img_3.png',bbox_inches='tight')

# %%
def drawDisk(img,c,r):

  img_height=img.shape[0]
  imgH=np.array(range(img_height))/(img_height-1)*2-1

  for i in range(img_height):
    for j in range(img_height):
      z=complex(imgH[i],imgH[j])
      if abs(z-c)<r:
        img[i,j]=0

  return img

# %%
def augImg3(img):

  img_height=img.shape[0]

  imgH=np.array(range(img_height))/(img_height-1)*2-1
 
  u=imgH[1]-imgH[0]

  img1=np.zeros((img.shape))
  img2=np.zeros((img.shape))
  img3=np.zeros((img.shape))

  for i in range(img_height):
    for j in range(img_height):
      z=complex(imgH[i],imgH[j])
      x=f(z)
      kul=math.pi/3
      y=x*cmath.exp(kul*1j)
      alp=0.1+0.1j
      v=(y+alp)/(1+np.conj(alp)*y)
      w=invf(v)
      i0=min(int(np.floor((w.real+1)/u)),img_height-2)
      i1=(w.real+1)/u-i0
      j0=min(int(np.floor((w.imag+1)/u)),img_height-2)
      j1=(w.imag+1)/u-j0
      img1[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]
      kul=math.pi
      y=x*cmath.exp(kul*1j)
      alp=0.1+0.3j
      v=(y+alp)/(1+np.conj(alp)*y)
      w=invf(v)
      i0=min(int(np.floor((w.real+1)/u)),img_height-2)
      i1=(w.real+1)/u-i0
      j0=min(int(np.floor((w.imag+1)/u)),img_height-2)
      j1=(w.imag+1)/u-j0
      img2[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]
      kul=1.5*math.pi
      y=x*cmath.exp(kul*1j)
      alp=0.3+0.3j
      v=(y+alp)/(1+np.conj(alp)*y)
      w=invf(v)
      i0=min(int(np.floor((w.real+1)/u)),img_height-2)
      i1=(w.real+1)/u-i0
      j0=min(int(np.floor((w.imag+1)/u)),img_height-2)
      j1=(w.imag+1)/u-j0
      img3[i,j]=i1*j1*img[i0,j0]+(1-i1)*j1*img[i0+1,j0]+i1*(1-j1)*img[i0,j0+1]+(1-i1)*(1-j1)*img[i0+1,j0+1]

  return [img1,img2,img3]

# %%
img_height=300
img=np.ones((img_height,img_height))
numOfDisks=10
c1=[np.random.uniform(low=-0.7,high=0.7)+np.random.uniform(low=-0.7,high=0.7)*1j]
for i in range(numOfDisks-1):
    c=np.random.uniform(low=-0.7,high=0.7)+np.random.uniform(low=-0.7,high=0.7)*1j
    while(min(abs(np.array(c1)-c))<0.4):
        c=np.random.uniform(low=-0.7,high=0.7)+np.random.uniform(low=-0.7,high=0.7)*1j
    c1.append(c)
r1=np.random.uniform(low=0.1,high=0.17,size=numOfDisks)
for i in range(numOfDisks):
    img=drawDisk(img,c1[i],r1[i])
plt.imshow(img,cmap='gray')
plt.show()

# %%
plt.imshow(img,cmap='gray')
fig=plt.gcf()
plt.axis('off')
plt.show()
fig.savefig('img_4_{}.png'.format(numOfDisks),bbox_inches='tight')

# %%
img1,img2,img3=augImg3(img)
plt.imshow(img,cmap='gray')
plt.show()
plt.imshow(img1,cmap='gray')
plt.show()
plt.imshow(img2,cmap='gray')
plt.show()
plt.imshow(img3,cmap='gray')
plt.show()

# %%
plt.imshow(img,cmap='gray')
fig=plt.gcf()
plt.axis('off')
plt.show()
fig.savefig('img0_{}.png'.format(numOfDisks),bbox_inches='tight')
plt.imshow(img1,cmap='gray')
fig=plt.gcf()
plt.axis('off')
plt.show()
fig.savefig('img1_{}.png'.format(numOfDisks),bbox_inches='tight')
plt.imshow(img2,cmap='gray')
fig=plt.gcf()
plt.axis('off')
plt.show()
fig.savefig('img2_{}.png'.format(numOfDisks),bbox_inches='tight')
plt.imshow(img3,cmap='gray')
fig=plt.gcf()
plt.axis('off')
plt.show()
fig.savefig('img3_{}.png'.format(numOfDisks),bbox_inches='tight')

# %%
plt.imshow(img,cmap='gray')
fig=plt.gcf()
plt.axis('off')
plt.show()
fig.savefig('img_35_0_{}.png'.format(numOfDisks),bbox_inches='tight')

# %%
plt.imshow(img,cmap='gray')
plt.show()
img1=squareToDisk(img)
plt.imshow(img1,cmap='gray')
plt.show()
alp=0.3+0.3j
img2=mobius(img1,alp)
plt.imshow(img2,cmap='gray')
plt.show()
kul=math.pi/3
img3=rotation(img2,kul)
plt.imshow(img3,cmap='gray')
plt.show()
img4=diskToSquare(img3)
plt.imshow(img4,cmap='gray')
plt.show()

# %%
for i in range(img_height):
  for j in range(img_height):
    if i<15 or i>img_height-15 or j<15 or j>img_height-15:
      img4[i,j]=1
    if img4[i,j]<0.5:
      img4[i,j]=0
    if img4[i,j]>0.5:
      img4[i,j]=1
plt.imshow(img4,cmap='gray')

# %%
plt.imshow(img,cmap='gray')
fig=plt.gcf()
plt.axis('off')
plt.show()
fig.savefig('img_3_0_{}.png'.format(numOfDisks),bbox_inches='tight')

# %%
os.listdir()
# Out:
# ['confF.ipynb',
#  'img0_1.png',
#  'img0_10.png',
#  'img0_2.png',
#  'img0_3.png',
#  'img0_4.png',
#  'img0_5.png',
#  'img0_6.png',
#  'img0_7.png',
#  'img0_8.png',
#  'img0_9.png',
#  'img1_1.png',
#  'img1_10.png',
#  'img1_2.png',
#  'img1_3.png',
#  'img1_4.png',
#  'img1_5.png',
#  'img1_6.png',
#  'img1_7.png',
#  'img1_8.png',
#  'img1_9.png',
#  'img2_1.png',
#  'img2_10.png',
#  'img2_2.png',
#  'img2_3.png',
#  'img2_4.png',
#  'img2_5.png',
#  'img2_6.png',
#  'img2_7.png',
#  'img2_8.png',
#  'img2_9.png',
#  'img3_1.png',
#  'img3_10.png',
#  'img3_2.png',
#  'img3_3.png',
#  'img3_4.png',
#  'img3_5.png',
#  'img3_6.png',
#  'img3_7.png',
#  'img3_8.png',
#  'img3_9.png',
#  'img_1_1.png',
#  'img_1_10.png',
#  'img_1_2.png',
#  'img_1_3.png',
#  'img_1_4.png',
#  'img_1_5.png',
#  'img_1_6.png',
#  'img_1_7.png',
#  'img_1_8.png',
#  'img_1_9.png',
#  'img_2_1.png',
#  'img_2_10.png',
#  'img_2_2.png',
#  'img_2_3.png',
#  'img_2_4.png',
#  'img_2_5.png',
#  'img_2_6.png',
#  'img_2_7.png',
#  'img_2_8.png',
#  'img_2_9.png',
#  'img_3_1.png',
#  'img_3_10.png',
#  'img_3_2.png',
#  'img_3_3.png',
#  'img_3_4.png',
#  'img_3_5.png',
#  'img_3_6.png',
#  'img_3_7.png',
#  'img_3_8.png',
#  'img_3_9.png',
#  'img_4_1.png',
#  'img_4_10.png',
#  'img_4_2.png',
#  'img_4_3.png',
#  'img_4_4.png',
#  'img_4_5.png',
#  'img_4_6.png',
#  'img_4_7.png',
#  'img_4_8.png',
#  'img_4_9.png',
#  'mobius.ipynb',
#  'polar_map_data',
#  'square.ipynb']

# %%
lfiles=os.listdir()
x_train=[]
x_train1=[]
y_train=[]
y_train1=[]
x_test=[]
y_test=[]

for i in range(len(lfiles)):

    if lfiles[i][0:4]=='img0':
        x_train.append(cv2.resize(cv2.imread('C:/Users/Oona/Documents/Tpc/func/data/{}'.format(lfiles[i])),(128,128)))
        num=int(lfiles[i][-5])
        if num==0:
            num=10
        y_train.append(num)
        
    if lfiles[i][0:4]=='img0' or lfiles[i][0:4]=='img1' or lfiles[i][0:4]=='img2' or lfiles[i][0:4]=='img3':
        x_train1.append(cv2.resize(cv2.imread('C:/Users/Oona/Documents/Tpc/func/data/{}'.format(lfiles[i])),(128,128)))
        num=int(lfiles[i][-5])
        if num==0:
            num=10
        y_train1.append(num)

    if lfiles[i][0:4]=='img_':
        if lfiles[i][4]!='f':
            x_test.append(cv2.resize(cv2.imread('C:/Users/Oona/Documents/Tpc/func/data/{}'.format(lfiles[i])),(128,128)))
            num=int(lfiles[i][-5])
            if num==0:
                num=10
            y_test.append(num)

x_train=np.array(x_train)[:,:,:,0]
x_train1=np.array(x_train1)[:,:,:,0]
y_train=np.array(y_train)
y_train1=np.array(y_train1)
x_test=np.array(x_test)[:,:,:,0]
y_test=np.array(y_test)

# %%
plt.imshow(x_train1[37],cmap='gray')
fig=plt.gcf()
plt.xticks([],labels='')
plt.yticks([],labels='')
plt.tick_params(left = False,top=False)
plt.show()
fig.savefig('img_f_7_3.png',bbox_inches='tight')

# %%
def Unet():
    
    model = keras.Sequential([layers.Conv2D(16, 3, activation='relu', input_shape=(128,128,1)),
                        layers.Conv2D(16, 3, activation='relu'),
                        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
                        layers.Conv2D(32, 3, activation='relu'),
                        layers.Conv2D(32, 3, activation='relu'),
                        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
                        layers.Conv2D(64, 3, activation='relu'),
                        layers.Conv2D(64, 3, activation='relu'),
                        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
                        layers.Conv2D(128, 3, activation='relu'),
                        layers.Conv2D(128, 3, activation='relu'),
                        layers.MaxPooling2D(strides=(2, 2)),
                        layers.Flatten(),
                        layers.Dense(128, activation='relu'),
                        layers.Dense(64, activation='relu'),
                        layers.Dense(32, activation='relu'),
                        layers.Dense(1, activation='linear')
    ]
    )

    return model

model=Unet()
numEpochs=130
model.compile(optimizer=keras.optimizers.Adam(1e-3),
            loss=keras.losses.MeanSquaredError(),
            metrics=[keras.metrics.MeanSquaredError()])
history=model.fit(x=x_train,y=y_train,epochs=numEpochs,validation_split=0.3,shuffle=True)
trainPreds=model.predict(x_train)
predictions=model.predict(x_test)
plt.plot(range(numEpochs),history.history['loss'],color='blue')
# Out:
# Epoch 1/130
# 1/1 [==============================] - 2s 2s/step - loss: 124.6218 - mean_squared_error: 124.6218 - val_loss: 48.5661 - val_mean_squared_error: 48.5661
# Epoch 2/130
# 1/1 [==============================] - 0s 390ms/step - loss: 20.4460 - mean_squared_error: 20.4460 - val_loss: 4.4425 - val_mean_squared_error: 4.4425
# Epoch 3/130
# 1/1 [==============================] - 0s 325ms/step - loss: 32.3068 - mean_squared_error: 32.3068 - val_loss: 23.6575 - val_mean_squared_error: 23.6575
# Epoch 4/130
# 1/1 [==============================] - 0s 338ms/step - loss: 8.8612 - mean_squared_error: 8.8612 - val_loss: 15.0181 - val_mean_squared_error: 15.0181
# Epoch 5/130
.071279525756836], [7.895195960998535], [8.098861694335938], [8.205734252929688], [1.1258571147918701], [9.34673023223877], [4.219010353088379], [4.088553428649902], [5.6164021492004395], [7.220080375671387], [7.516451835632324], [6.229600429534912], [8.50709342956543], [8.463285446166992], [3.721836566925049], [9.81179141998291], [4.4482526779174805], [5.687618255615234], [4.401947498321533], [5.638334274291992], [7.395411491394043], [8.28422737121582], [9.311017990112305], [8.741544723510742], [1.2843598127365112], [9.097321510314941], [3.0582528114318848], [3.5880179405212402], [4.760104656219482], [7.109034061431885], [6.413276195526123], [7.901362895965576], [8.092206001281738], [8.227804183959961], [1.2438942193984985], [9.905495643615723], [2.143103837966919], [4.620383262634277], [5.315472602844238], [5.658945083618164], [7.1719536781311035], [8.668255805969238], [9.658711433410645], [9.38206958770752], [1.3091286420822144], [9.139426231384277], [2.7990903854370117], [3.3648407459259033], [6.505838394165039], [6.07994270324707], [7.0886454582214355], [6.873944282531738], [8.60366153717041], [7.425411224365234], [3.4491162300109863], [8.705061912536621], [3.5676231384277344], [5.593603610992432], [7.041362762451172], [6.8649492263793945], [7.668285369873047], [5.792200088500977], [7.691423416137695], [9.641572952270508], [3.43558406829834], [9.801902770996094], [1.6148097515106201], [4.634629726409912], [4.4135894775390625], [4.566171646118164], [7.52923583984375], [5.632936954498291], [7.001075744628906], [9.701035499572754]])

# %%
np.savetxt('trainPreds.txt',trainPreds)
np.savetxt('trainPreds1.txt',trainPreds1)
np.savetxt('predictions.txt',predictions)
np.savetxt('predictions1.txt',predictions1)

# %%
trainPreds=np.loadtxt('trainPreds.txt')
trainPreds1=np.loadtxt('trainPreds1.txt')
predictions=np.loadtxt('predictions.txt')
predictions1=np.loadtxt('predictions1.txt')

# %%
t=[]
for i in range(10):
    t.append((trainPreds[i]-y_train[i])**2)
print(np.mean(t))
t1=[]
for i in range(40):
    t1.append((trainPreds1[i]-y_train1[i])**2)
print(np.mean(t1))
u=[]
for i in range(160):
    u.append((predictions[i]-y_test[i])**2)
print(np.mean(u))  
u1=[]
for i in range(160):
    u1.append((predictions1[i]-y_test[i])**2)
print(np.mean(u1))
print((np.mean(u)-np.mean(u1))/(np.mean(u)))
# Out:
# 0.23124723535447203
# 0.613244077781547
# 2.3808488993765105
# 1.7427902897110894
# 0.2679962637832724

# %%
print(ttest_ind(u,u1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Oona\Documents\Pet\mobius\confF.ipynb Cell 32 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Oona/Documents/Pet/mobius/confF.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> print(ttest_ind(u,u1))
#
# NameError: name 'u' is not defined

# %%
np.corrcoef(y_test,predictions)
# Out:
# array([[1.        , 0.88445803],
#        [0.88445803, 1.        ]])

# %%
b,a=np.polyfit(y_test,predictions1,deg=1)
print(a)
print(b)
# Out:
# 1.845625679691632
# 0.7927584674322243

# %%
plt.scatter(y_test,predictions1,color='blue')
plt.plot(y_test,b*y_test+a,color='black')
fig=plt.gcf()
plt.show()
fig.savefig('preds1.png',bbox_inches='tight')
